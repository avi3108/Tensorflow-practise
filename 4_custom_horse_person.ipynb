# %%
import os


train_horse_dir = os.path.join('/home/avi/Downloads/interview/python_codes/Tensorflow/images/train/horses')
train_horse_dir
train_human_dir = os.path.join('/home/avi/Downloads/interview/python_codes/Tensorflow/images/train/humans')
train_human_dir
# Out:
# '/home/avi/Downloads/interview/python_codes/Tensorflow/images/train/humans'

# %%
train_horse_name = os.listdir(train_horse_dir)
train_horse_name

train_human_name = os.listdir(train_human_dir)
train_human_name
# Out:
# ['human11-24.png',
#  'human01-18.png',
#  'human05-14.png',
#  'human05-25.png',
#  'human10-07.png',
#  'human01-04.png',
#  'human07-16.png',
#  'human13-20.png',
#  'human04-07.png',
#  'human10-29.png',
#  'human16-19.png',
#  'human02-16.png',
#  'human05-27.png',
#  'human16-01.png',
#  'human16-10.png',
#  'human01-23.png',
#  'human12-25.png',
#  'human07-22.png',
#  'human02-29.png',
#  'human12-24.png',
#  'human09-01.png',
#  'human16-07.png',
#  'human11-15.png',
#  'human15-18.png',
#  'human02-25.png',
#  'human06-28.png',
#  'human16-12.png',
#  'human13-06.png',
#  'human17-14.png',
#  'human17-27.png',
#  'human05-17.png',
#  'human04-09.png',
#  'human05-11.png',
#  'human09-14.png',
#  'human11-09.png',
#  'human03-23.png',
#  'human15-15.png',
#  'human04-10.png',
#  'human10-26.png',
#  'human12-29.png',
#  'human09-25.png',
#  'human05-18.png',
#  'human17-30.png',
#  'human11-27.png',
#  'human10-15.png',
#  'human07-30.png',
#  'human04-11.png',
# ...

# %%
print("length of horse data :",len(train_horse_name))
print("length of human data :",len(train_human_name))
# Out:
# length of horse data : 500
# length of human data : 527

# %%
import tensorflow as tf

# %%
from tensorflow.keras.layers import Conv2D,Flatten,Dense,MaxPool2D

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16,(3,3), activation = 'relu',input_shape=(300,300,3)),
    tf.keras.layers.MaxPool2D(2,2),

    tf.keras.layers.Conv2D(32,(3,3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(2,2),

    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(2,2),


    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(2,2),


    tf.keras.layers.Conv2D(64,(3,3), activation = 'relu'),
    tf.keras.layers.MaxPool2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation = "relu"),
    tf.keras.layers.Dense(1,activation = "sigmoid")

])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_31 (Conv2D)          (None, 298, 298, 16)      448
#
#  max_pooling2d_31 (MaxPoolin  (None, 149, 149, 16)     0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 147, 147, 32)      4640
#
#  max_pooling2d_32 (MaxPoolin  (None, 73, 73, 32)       0
#  g2D)
#
#  conv2d_33 (Conv2D)          (None, 71, 71, 64)        18496
#
#  max_pooling2d_33 (MaxPoolin  (None, 35, 35, 64)       0
#  g2D)
#
#  conv2d_34 (Conv2D)          (None, 33, 33, 64)        36928
#
#  max_pooling2d_34 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  conv2d_35 (Conv2D)          (None, 14, 14, 64)        36928
#
#  max_pooling2d_35 (MaxPoolin  (None, 7, 7, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 3136)              0
#
#  dense_13 (Dense)            (None, 512)               1606144
#
# ...

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(loss="binary_crossentropy",optimizer=RMSprop(learning_rate=0.001), metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale= 1/255)

train_generator = train_datagen.flow_from_directory(
    './images/train/',
    target_size =(300,300),
    batch_size = 128,
    class_mode = 'binary'
)
# Out:
# Found 1027 images belonging to 2 classes.

# %%
history = model.fit(
    train_generator,
    steps_per_epoch = 8,
    epochs = 10,
    verbose=1)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 36s 5s/step - loss: 0.7122 - accuracy: 0.6107
# Epoch 2/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.5537 - accuracy: 0.7019
# Epoch 3/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.3995 - accuracy: 0.8320
# Epoch 4/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.4991 - accuracy: 0.8387
# Epoch 5/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.1855 - accuracy: 0.9366
# Epoch 6/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.1191 - accuracy: 0.9522
# Epoch 7/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.1565 - accuracy: 0.9422
# Epoch 8/10
# 8/8 [==============================] - 41s 5s/step - loss: 0.3738 - accuracy: 0.8954
# Epoch 9/10
# 8/8 [==============================] - 42s 5s/step - loss: 0.2226 - accuracy: 0.9077
# Epoch 10/10
# ...

# %%
model.evaluate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_224919/271906568.py in <module>
# ----> 1 model.evaluate()
#
# ~/anaconda3/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/data_adapter.py in select_data_adapter(x, y)
#    1081         raise ValueError(
#    1082             "Failed to find data adapter that can handle input: {}, {}".format(
# -> 1083                 _type_name(x), _type_name(y)
#    1084             )
#    1085         )
#
# ...

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img("/home/avi/Downloads/interview/python_codes/Tensorflow/test_images/horse6.jpg",target_size=(300,300))
x = image.img_to_array(img)
x/=255
x = np.expand_dims(x,axis=0)

images = np.vstack([x])

classes = model.predict(images)
print(classes[0])

if classes[0]>0.5:
    print("is human")
else:
    print("is horse")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# [2.5555339e-11]
# is horse

# %% [markdown]
# !pip install google.com
